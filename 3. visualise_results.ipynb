# %% [markdown]
# # 6. Performance Evaluation for Model Tuning

# %%
import os
import time

from functions.tuning import Tuner
from functions.plotting import Plotter

# %matplotlib inline

# %%
# Set hyperparameters
BATCH_SIZES = [32, 64, 128] # samples per batch to load
H_LAYERS = [[256, 256], [512, 256], [512, 512], [1024, 516]]
SPLIT_SIZE = 0.15 # validation & test dataset size
N_PREDS = 5 # number of model predictions (e.g. top-5 error rate)
N_CLASSES = 35 # number of classes
MAIN_FILEPATH = 'dataset/resized'
SAVE_FOLDER = 'saved_models'
MODEL_NAMES = ["GoogLeNet", "MobileNet-V2", "ResNet-34"]
SEED = 1

# %% [markdown]
# ## 6.1 Data Preparation

# %%
# Set tune class object
tune = Tuner()
# Out:
# CUDA is available. Device has been set to GPU.

# %%
# Transform the dataset
dataset = tune.set_data(MAIN_FILEPATH)

# %%
# Set plot class object
vis = Plotter(tune.labels)
# Out:
# CUDA is available. Device has been set to GPU.

# %% [markdown]
# ## 6.2 Visualise Results

# %%
model_stats = []
count = 1

start_time = time.time()
for i in range(len(BATCH_SIZES)):
    # Split data
    _, _, test_loader = tune.utils.split_data(dataset, BATCH_SIZES[i], SPLIT_SIZE, SEED)
    
    for h in range(len(H_LAYERS)):
        # Retrieve model filepaths and set initial models
        model_paths = os.listdir(SAVE_FOLDER)
        cnn_models = tune._set_initial_models(N_CLASSES, H_LAYERS[h])
        N_MODELS = (len(BATCH_SIZES) * len(H_LAYERS)) * len(cnn_models)
        
        # Calculate predictions, test labels, and probabilities
        for m in range(len(cnn_models)):
            model, name = tune.set_model(model_paths, cnn_models[m], MODEL_NAMES[m])
            print(f"Calculating preds and stats for {name}...", end=" ")
            y_pred, y_true = tune.utils.predict(model, test_loader, 
                                                store_labels=True)
            
            # Calculate statistics
            model_stats.append(tune.utils.calc_statistics(model, name, test_loader, 
                                                          y_pred, y_true, N_PREDS))
            print(f"Complete ({count}/{N_MODELS}).")
            count += 1
tune.utils.time_taken(time.time() - start_time)
print("Plotting statistics...")
all_stats = vis.plot_stats(model_stats)
# Out:
# Calculating preds and stats for GoogLeNet_32_256_256... Complete (1/36).
# Calculating preds and stats for MobileNet-V2_32_256_256... Complete (2/36).
# Calculating preds and stats for ResNet-34_32_256_256... Complete (3/36).
# Calculating preds and stats for GoogLeNet_32_512_256... Complete (4/36).
# Calculating preds and stats for MobileNet-V2_32_512_256... Complete (5/36).
# Calculating preds and stats for ResNet-34_32_512_256... Complete (6/36).
# Calculating preds and stats for GoogLeNet_32_512_512... Complete (7/36).
# Calculating preds and stats for MobileNet-V2_32_512_512... Complete (8/36).
# Calculating preds and stats for ResNet-34_32_512_512... Complete (9/36).
# Calculating preds and stats for GoogLeNet_32_1024_516... Complete (10/36).
# Calculating preds and stats for MobileNet-V2_32_1024_516... Complete (11/36).
# Calculating preds and stats for ResNet-34_32_1024_516... Complete (12/36).
# Calculating preds and stats for GoogLeNet_64_256_256... Complete (13/36).
# Calculating preds and stats for MobileNet-V2_64_256_256... Complete (14/36).
# Calculating preds and stats for ResNet-34_64_256_256... Complete (15/36).
# Calculating preds and stats for GoogLeNet_64_512_256... Complete (16/36).
# Calculating preds and stats for MobileNet-V2_64_512_256... Complete (17/36).
# Calculating preds and stats for ResNet-34_64_512_256... Complete (18/36).
# Calculating preds and stats for GoogLeNet_64_512_512... Complete (19/36).
# Calculating preds and stats for MobileNet-V2_64_512_512... Complete (20/36).
# Calculating preds and stats for ResNet-34_64_512_512... Complete (21/36).
# Calculating preds and stats for GoogLeNet_64_1024_516... Complete (22/36).
# Calculating preds and stats for MobileNet-V2_64_1024_516... Complete (23/36).
# Calculating preds and stats for ResNet-34_64_1024_516... Complete (24/36).
# Calculating preds and stats for GoogLeNet_128_256_256... Complete (25/36).
# Calculating preds and stats for MobileNet-V2_128_256_256... Complete (26/36).
# Calculating preds and stats for ResNet-34_128_256_256... Complete (27/36).
# Calculating preds and stats for GoogLeNet_128_512_256... Complete (28/36).
# Calculating preds and stats for MobileNet-V2_128_512_256... Complete (29/36).
# Calculating preds and stats for ResNet-34_128_512_256... Complete (30/36).
# Calculating preds and stats for GoogLeNet_128_512_512... Complete (31/36).
# Calculating preds and stats for MobileNet-V2_128_512_512... Complete (32/36).
# Calculating preds and stats for ResNet-34_128_512_512... Complete (33/36).
# Calculating preds and stats for GoogLeNet_128_1024_516... Complete (34/36).
# Calculating preds and stats for MobileNet-V2_128_1024_516... Complete (35/36).
# Calculating preds and stats for ResNet-34_128_1024_516... Complete (36/36).
# Total time taken: 1.00 hrs 17.00 mins 30.76 secs
# Plotting statistics...

# %%
all_stats[all_stats['Name'].str.contains(MODEL_NAMES[0])].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ef890_" ><thead>    <tr>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Top-1 Error</th>        <th class="col_heading level0 col3" >Top-5 Error</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F1-Score</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ef890_row0_col0" class="data row0 col0" >GoogLeNet_32_256_256</td>
#                         <td id="T_ef890_row0_col1" class="data row0 col1" >0.674738</td>
#                         <td id="T_ef890_row0_col2" class="data row0 col2" >0.325262</td>
#                         <td id="T_ef890_row0_col3" class="data row0 col3" >0.286521</td>
#                         <td id="T_ef890_row0_col4" class="data row0 col4" >0.535714</td>
#                         <td id="T_ef890_row0_col5" class="data row0 col5" >0.542169</td>
#                         <td id="T_ef890_row0_col6" class="data row0 col6" >0.538922</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row1_col0" class="data row1 col0" >GoogLeNet_32_512_256</td>
#                         <td id="T_ef890_row1_col1" class="data row1 col1" >0.700969</td>
#                         <td id="T_ef890_row1_col2" class="data row1 col2" >0.299031</td>
#                         <td id="T_ef890_row1_col3" class="data row1 col3" >0.274011</td>
#                         <td id="T_ef890_row1_col4" class="data row1 col4" >0.640000</td>
#                         <td id="T_ef890_row1_col5" class="data row1 col5" >0.738462</td>
#                         <td id="T_ef890_row1_col6" class="data row1 col6" >0.685714</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row2_col0" class="data row2 col0" >GoogLeNet_32_512_512</td>
#                         <td id="T_ef890_row2_col1" class="data row2 col1" >0.682002</td>
#                         <td id="T_ef890_row2_col2" class="data row2 col2" >0.317998</td>
#                         <td id="T_ef890_row2_col3" class="data row2 col3" >0.284504</td>
#                         <td id="T_ef890_row2_col4" class="data row2 col4" >0.696970</td>
#                         <td id="T_ef890_row2_col5" class="data row2 col5" >0.567901</td>
#                         <td id="T_ef890_row2_col6" class="data row2 col6" >0.625850</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row3_col0" class="data row3 col0" >GoogLeNet_32_1024_516</td>
#                         <td id="T_ef890_row3_col1" class="data row3 col1" >0.711057</td>
#                         <td id="T_ef890_row3_col2" class="data row3 col2" >0.288943</td>
#                         <td id="T_ef890_row3_col3" class="data row3 col3" >0.262308</td>
#                         <td id="T_ef890_row3_col4" class="data row3 col4" >0.750000</td>
#                         <td id="T_ef890_row3_col5" class="data row3 col5" >0.557143</td>
#                         <td id="T_ef890_row3_col6" class="data row3 col6" >0.639344</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row4_col0" class="data row4 col0" >GoogLeNet_64_256_256</td>
#                         <td id="T_ef890_row4_col1" class="data row4 col1" >0.705811</td>
#                         <td id="T_ef890_row4_col2" class="data row4 col2" >0.294189</td>
#                         <td id="T_ef890_row4_col3" class="data row4 col3" >0.257466</td>
#                         <td id="T_ef890_row4_col4" class="data row4 col4" >0.589744</td>
#                         <td id="T_ef890_row4_col5" class="data row4 col5" >0.647887</td>
#                         <td id="T_ef890_row4_col6" class="data row4 col6" >0.617450</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row5_col0" class="data row5 col0" >GoogLeNet_64_512_256</td>
#                         <td id="T_ef890_row5_col1" class="data row5 col1" >0.715496</td>
#                         <td id="T_ef890_row5_col2" class="data row5 col2" >0.284504</td>
#                         <td id="T_ef890_row5_col3" class="data row5 col3" >0.255044</td>
#                         <td id="T_ef890_row5_col4" class="data row5 col4" >0.795918</td>
#                         <td id="T_ef890_row5_col5" class="data row5 col5" >0.448276</td>
#                         <td id="T_ef890_row5_col6" class="data row5 col6" >0.573529</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row6_col0" class="data row6 col0" >GoogLeNet_64_512_512</td>
#                         <td id="T_ef890_row6_col1" class="data row6 col1" >0.715496</td>
#                         <td id="T_ef890_row6_col2" class="data row6 col2" >0.284504</td>
#                         <td id="T_ef890_row6_col3" class="data row6 col3" >0.255851</td>
#                         <td id="T_ef890_row6_col4" class="data row6 col4" >0.851852</td>
#                         <td id="T_ef890_row6_col5" class="data row6 col5" >0.484211</td>
#                         <td id="T_ef890_row6_col6" class="data row6 col6" >0.617450</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row7_col0" class="data row7 col0" >GoogLeNet_64_1024_516</td>
#                         <td id="T_ef890_row7_col1" class="data row7 col1" >0.735270</td>
#                         <td id="T_ef890_row7_col2" class="data row7 col2" >0.264730</td>
#                         <td id="T_ef890_row7_col3" class="data row7 col3" >0.235270</td>
#                         <td id="T_ef890_row7_col4" class="data row7 col4" >0.625000</td>
#                         <td id="T_ef890_row7_col5" class="data row7 col5" >0.757576</td>
#                         <td id="T_ef890_row7_col6" class="data row7 col6" >0.684932</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row8_col0" class="data row8 col0" >GoogLeNet_128_256_256</td>
#                         <td id="T_ef890_row8_col1" class="data row8 col1" >0.715900</td>
#                         <td id="T_ef890_row8_col2" class="data row8 col2" >0.284100</td>
#                         <td id="T_ef890_row8_col3" class="data row8 col3" >0.250202</td>
#                         <td id="T_ef890_row8_col4" class="data row8 col4" >0.789474</td>
#                         <td id="T_ef890_row8_col5" class="data row8 col5" >0.489130</td>
#                         <td id="T_ef890_row8_col6" class="data row8 col6" >0.604027</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row9_col0" class="data row9 col0" >GoogLeNet_128_512_256</td>
#                         <td id="T_ef890_row9_col1" class="data row9 col1" >0.733253</td>
#                         <td id="T_ef890_row9_col2" class="data row9 col2" >0.266747</td>
#                         <td id="T_ef890_row9_col3" class="data row9 col3" >0.236885</td>
#                         <td id="T_ef890_row9_col4" class="data row9 col4" >0.750000</td>
#                         <td id="T_ef890_row9_col5" class="data row9 col5" >0.711864</td>
#                         <td id="T_ef890_row9_col6" class="data row9 col6" >0.730435</td>
#             </tr>
#             <tr>
#                                 <td id="T_ef890_row10_col0" class="data row10 col0" >GoogLeNet_128_512_512</td>
#                         <td id="T_ef890_row10_col1" class="data row10 col1" >0.725989</td>
#                         <td id="T_ef890_row10_col2" class="data row10 col2" >0.274011</td>
#                         <td id="T_ef890_row10_col3" class="data row10 col3" >0.246166</td>
#                         <td id="T_ef890_row10_col4" class="data row10 col4" >0.785714</td>
#                         <td id="T_ef890_row10_col5" class="data row10 col5" >0.494382</td>
#                         <td id="T_ef890_row10_col6" class="data row10 col6" >0.606897</td>
#             </tr>
#             <tr>

# %%
all_stats[all_stats['Name'].str.contains(MODEL_NAMES[1])].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_a39e0_" ><thead>    <tr>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Top-1 Error</th>        <th class="col_heading level0 col3" >Top-5 Error</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F1-Score</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a39e0_row0_col0" class="data row0 col0" >MobileNet-V2_32_256_256</td>
#                         <td id="T_a39e0_row0_col1" class="data row0 col1" >0.762712</td>
#                         <td id="T_a39e0_row0_col2" class="data row0 col2" >0.237288</td>
#                         <td id="T_a39e0_row0_col3" class="data row0 col3" >0.214286</td>
#                         <td id="T_a39e0_row0_col4" class="data row0 col4" >0.768116</td>
#                         <td id="T_a39e0_row0_col5" class="data row0 col5" >0.803030</td>
#                         <td id="T_a39e0_row0_col6" class="data row0 col6" >0.785185</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row1_col0" class="data row1 col0" >MobileNet-V2_32_512_256</td>
#                         <td id="T_a39e0_row1_col1" class="data row1 col1" >0.762712</td>
#                         <td id="T_a39e0_row1_col2" class="data row1 col2" >0.237288</td>
#                         <td id="T_a39e0_row1_col3" class="data row1 col3" >0.211461</td>
#                         <td id="T_a39e0_row1_col4" class="data row1 col4" >0.758621</td>
#                         <td id="T_a39e0_row1_col5" class="data row1 col5" >0.536585</td>
#                         <td id="T_a39e0_row1_col6" class="data row1 col6" >0.628571</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row2_col0" class="data row2 col0" >MobileNet-V2_32_512_512</td>
#                         <td id="T_a39e0_row2_col1" class="data row2 col1" >0.788136</td>
#                         <td id="T_a39e0_row2_col2" class="data row2 col2" >0.211864</td>
#                         <td id="T_a39e0_row2_col3" class="data row2 col3" >0.187248</td>
#                         <td id="T_a39e0_row2_col4" class="data row2 col4" >0.556701</td>
#                         <td id="T_a39e0_row2_col5" class="data row2 col5" >0.580645</td>
#                         <td id="T_a39e0_row2_col6" class="data row2 col6" >0.568421</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row3_col0" class="data row3 col0" >MobileNet-V2_32_1024_516</td>
#                         <td id="T_a39e0_row3_col1" class="data row3 col1" >0.769572</td>
#                         <td id="T_a39e0_row3_col2" class="data row3 col2" >0.230428</td>
#                         <td id="T_a39e0_row3_col3" class="data row3 col3" >0.207425</td>
#                         <td id="T_a39e0_row3_col4" class="data row3 col4" >0.705882</td>
#                         <td id="T_a39e0_row3_col5" class="data row3 col5" >0.666667</td>
#                         <td id="T_a39e0_row3_col6" class="data row3 col6" >0.685714</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row4_col0" class="data row4 col0" >MobileNet-V2_64_256_256</td>
#                         <td id="T_a39e0_row4_col1" class="data row4 col1" >0.782082</td>
#                         <td id="T_a39e0_row4_col2" class="data row4 col2" >0.217918</td>
#                         <td id="T_a39e0_row4_col3" class="data row4 col3" >0.191687</td>
#                         <td id="T_a39e0_row4_col4" class="data row4 col4" >0.761905</td>
#                         <td id="T_a39e0_row4_col5" class="data row4 col5" >0.516129</td>
#                         <td id="T_a39e0_row4_col6" class="data row4 col6" >0.615385</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row5_col0" class="data row5 col0" >MobileNet-V2_64_512_256</td>
#                         <td id="T_a39e0_row5_col1" class="data row5 col1" >0.806699</td>
#                         <td id="T_a39e0_row5_col2" class="data row5 col2" >0.193301</td>
#                         <td id="T_a39e0_row5_col3" class="data row5 col3" >0.173527</td>
#                         <td id="T_a39e0_row5_col4" class="data row5 col4" >0.595960</td>
#                         <td id="T_a39e0_row5_col5" class="data row5 col5" >0.710843</td>
#                         <td id="T_a39e0_row5_col6" class="data row5 col6" >0.648352</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row6_col0" class="data row6 col0" >MobileNet-V2_64_512_512</td>
#                         <td id="T_a39e0_row6_col1" class="data row6 col1" >0.802663</td>
#                         <td id="T_a39e0_row6_col2" class="data row6 col2" >0.197337</td>
#                         <td id="T_a39e0_row6_col3" class="data row6 col3" >0.179177</td>
#                         <td id="T_a39e0_row6_col4" class="data row6 col4" >0.705128</td>
#                         <td id="T_a39e0_row6_col5" class="data row6 col5" >0.647059</td>
#                         <td id="T_a39e0_row6_col6" class="data row6 col6" >0.674847</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row7_col0" class="data row7 col0" >MobileNet-V2_64_1024_516</td>
#                         <td id="T_a39e0_row7_col1" class="data row7 col1" >0.814366</td>
#                         <td id="T_a39e0_row7_col2" class="data row7 col2" >0.185634</td>
#                         <td id="T_a39e0_row7_col3" class="data row7 col3" >0.166667</td>
#                         <td id="T_a39e0_row7_col4" class="data row7 col4" >0.870370</td>
#                         <td id="T_a39e0_row7_col5" class="data row7 col5" >0.500000</td>
#                         <td id="T_a39e0_row7_col6" class="data row7 col6" >0.635135</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row8_col0" class="data row8 col0" >MobileNet-V2_128_256_256</td>
#                         <td id="T_a39e0_row8_col1" class="data row8 col1" >0.789750</td>
#                         <td id="T_a39e0_row8_col2" class="data row8 col2" >0.210250</td>
#                         <td id="T_a39e0_row8_col3" class="data row8 col3" >0.184019</td>
#                         <td id="T_a39e0_row8_col4" class="data row8 col4" >0.662651</td>
#                         <td id="T_a39e0_row8_col5" class="data row8 col5" >0.808824</td>
#                         <td id="T_a39e0_row8_col6" class="data row8 col6" >0.728477</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row9_col0" class="data row9 col0" >MobileNet-V2_128_512_256</td>
#                         <td id="T_a39e0_row9_col1" class="data row9 col1" >0.833333</td>
#                         <td id="T_a39e0_row9_col2" class="data row9 col2" >0.166667</td>
#                         <td id="T_a39e0_row9_col3" class="data row9 col3" >0.148103</td>
#                         <td id="T_a39e0_row9_col4" class="data row9 col4" >0.716049</td>
#                         <td id="T_a39e0_row9_col5" class="data row9 col5" >0.725000</td>
#                         <td id="T_a39e0_row9_col6" class="data row9 col6" >0.720497</td>
#             </tr>
#             <tr>
#                                 <td id="T_a39e0_row10_col0" class="data row10 col0" >MobileNet-V2_128_512_512</td>
#                         <td id="T_a39e0_row10_col1" class="data row10 col1" >0.818805</td>
#                         <td id="T_a39e0_row10_col2" class="data row10 col2" >0.181195</td>
#                         <td id="T_a39e0_row10_col3" class="data row10 col3" >0.163035</td>
#                         <td id="T_a39e0_row10_col4" class="data row10 col4" >0.787879</td>
#                         <td id="T_a39e0_row10_col5" class="data row10 col5" >0.626506</td>
#                         <td id="T_a39e0_row10_col6" class="data row10 col6" >0.697987</td>

# %%
all_stats[all_stats['Name'].str.contains(MODEL_NAMES[-1])].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_36263_" ><thead>    <tr>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Top-1 Error</th>        <th class="col_heading level0 col3" >Top-5 Error</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F1-Score</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_36263_row0_col0" class="data row0 col0" >ResNet-34_32_256_256</td>
#                         <td id="T_36263_row0_col1" class="data row0 col1" >0.723971</td>
#                         <td id="T_36263_row0_col2" class="data row0 col2" >0.276029</td>
#                         <td id="T_36263_row0_col3" class="data row0 col3" >0.248991</td>
#                         <td id="T_36263_row0_col4" class="data row0 col4" >0.671429</td>
#                         <td id="T_36263_row0_col5" class="data row0 col5" >0.618421</td>
#                         <td id="T_36263_row0_col6" class="data row0 col6" >0.643836</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row1_col0" class="data row1 col0" >ResNet-34_32_512_256</td>
#                         <td id="T_36263_row1_col1" class="data row1 col1" >0.742938</td>
#                         <td id="T_36263_row1_col2" class="data row1 col2" >0.257062</td>
#                         <td id="T_36263_row1_col3" class="data row1 col3" >0.229621</td>
#                         <td id="T_36263_row1_col4" class="data row1 col4" >0.786885</td>
#                         <td id="T_36263_row1_col5" class="data row1 col5" >0.640000</td>
#                         <td id="T_36263_row1_col6" class="data row1 col6" >0.705882</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row2_col0" class="data row2 col0" >ResNet-34_32_512_512</td>
#                         <td id="T_36263_row2_col1" class="data row2 col1" >0.761905</td>
#                         <td id="T_36263_row2_col2" class="data row2 col2" >0.238095</td>
#                         <td id="T_36263_row2_col3" class="data row2 col3" >0.211057</td>
#                         <td id="T_36263_row2_col4" class="data row2 col4" >0.732394</td>
#                         <td id="T_36263_row2_col5" class="data row2 col5" >0.732394</td>
#                         <td id="T_36263_row2_col6" class="data row2 col6" >0.732394</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row3_col0" class="data row3 col0" >ResNet-34_32_1024_516</td>
#                         <td id="T_36263_row3_col1" class="data row3 col1" >0.738095</td>
#                         <td id="T_36263_row3_col2" class="data row3 col2" >0.261905</td>
#                         <td id="T_36263_row3_col3" class="data row3 col3" >0.232042</td>
#                         <td id="T_36263_row3_col4" class="data row3 col4" >0.724138</td>
#                         <td id="T_36263_row3_col5" class="data row3 col5" >0.531646</td>
#                         <td id="T_36263_row3_col6" class="data row3 col6" >0.613139</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row4_col0" class="data row4 col0" >ResNet-34_64_256_256</td>
#                         <td id="T_36263_row4_col1" class="data row4 col1" >0.752623</td>
#                         <td id="T_36263_row4_col2" class="data row4 col2" >0.247377</td>
#                         <td id="T_36263_row4_col3" class="data row4 col3" >0.223164</td>
#                         <td id="T_36263_row4_col4" class="data row4 col4" >0.772727</td>
#                         <td id="T_36263_row4_col5" class="data row4 col5" >0.586207</td>
#                         <td id="T_36263_row4_col6" class="data row4 col6" >0.666667</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row5_col0" class="data row5 col0" >ResNet-34_64_512_256</td>
#                         <td id="T_36263_row5_col1" class="data row5 col1" >0.782486</td>
#                         <td id="T_36263_row5_col2" class="data row5 col2" >0.217514</td>
#                         <td id="T_36263_row5_col3" class="data row5 col3" >0.193301</td>
#                         <td id="T_36263_row5_col4" class="data row5 col4" >0.753846</td>
#                         <td id="T_36263_row5_col5" class="data row5 col5" >0.653333</td>
#                         <td id="T_36263_row5_col6" class="data row5 col6" >0.700000</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row6_col0" class="data row6 col0" >ResNet-34_64_512_512</td>
#                         <td id="T_36263_row6_col1" class="data row6 col1" >0.760694</td>
#                         <td id="T_36263_row6_col2" class="data row6 col2" >0.239306</td>
#                         <td id="T_36263_row6_col3" class="data row6 col3" >0.211057</td>
#                         <td id="T_36263_row6_col4" class="data row6 col4" >0.662500</td>
#                         <td id="T_36263_row6_col5" class="data row6 col5" >0.546392</td>
#                         <td id="T_36263_row6_col6" class="data row6 col6" >0.598870</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row7_col0" class="data row7 col0" >ResNet-34_64_1024_516</td>
#                         <td id="T_36263_row7_col1" class="data row7 col1" >0.776836</td>
#                         <td id="T_36263_row7_col2" class="data row7 col2" >0.223164</td>
#                         <td id="T_36263_row7_col3" class="data row7 col3" >0.196933</td>
#                         <td id="T_36263_row7_col4" class="data row7 col4" >0.800000</td>
#                         <td id="T_36263_row7_col5" class="data row7 col5" >0.666667</td>
#                         <td id="T_36263_row7_col6" class="data row7 col6" >0.727273</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row8_col0" class="data row8 col0" >ResNet-34_128_256_256</td>
#                         <td id="T_36263_row8_col1" class="data row8 col1" >0.748588</td>
#                         <td id="T_36263_row8_col2" class="data row8 col2" >0.251412</td>
#                         <td id="T_36263_row8_col3" class="data row8 col3" >0.227199</td>
#                         <td id="T_36263_row8_col4" class="data row8 col4" >0.727273</td>
#                         <td id="T_36263_row8_col5" class="data row8 col5" >0.600000</td>
#                         <td id="T_36263_row8_col6" class="data row8 col6" >0.657534</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row9_col0" class="data row9 col0" >ResNet-34_128_512_256</td>
#                         <td id="T_36263_row9_col1" class="data row9 col1" >0.800242</td>
#                         <td id="T_36263_row9_col2" class="data row9 col2" >0.199758</td>
#                         <td id="T_36263_row9_col3" class="data row9 col3" >0.178773</td>
#                         <td id="T_36263_row9_col4" class="data row9 col4" >0.800000</td>
#                         <td id="T_36263_row9_col5" class="data row9 col5" >0.675325</td>
#                         <td id="T_36263_row9_col6" class="data row9 col6" >0.732394</td>
#             </tr>
#             <tr>
#                                 <td id="T_36263_row10_col0" class="data row10 col0" >ResNet-34_128_512_512</td>
#                         <td id="T_36263_row10_col1" class="data row10 col1" >0.799839</td>
#                         <td id="T_36263_row10_col2" class="data row10 col2" >0.200161</td>
#                         <td id="T_36263_row10_col3" class="data row10 col3" >0.176755</td>
#                         <td id="T_36263_row10_col4" class="data row10 col4" >0.724638</td>
#                         <td id="T_36263_row10_col5" class="data row10 col5" >0.694444</td>
#                         <td id="T_36263_row10_col6" class="data row10 col6" >0.709220</td>
#             </tr>
#             <tr>

# %%
# Retrieve best models stats
best_models = []
for name in MODEL_NAMES:
    models_split = all_stats[all_stats['Name'].str.contains(name)]
    
    # Get best model
    idx = models_split['Accuracy'].idxmax()
    best_model = all_stats.iloc[idx, :]
    best_models.append(best_model) # Store in list

# Plot stats
best_model_stats = vis.plot_stats(best_models)
best_model_stats.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_48dcb_" ><thead>    <tr>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Top-1 Error</th>        <th class="col_heading level0 col3" >Top-5 Error</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>        <th class="col_heading level0 col6" >F1-Score</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_48dcb_row0_col0" class="data row0 col0" >GoogLeNet_128_1024_516</td>
#                         <td id="T_48dcb_row0_col1" class="data row0 col1" >0.744149</td>
#                         <td id="T_48dcb_row0_col2" class="data row0 col2" >0.255851</td>
#                         <td id="T_48dcb_row0_col3" class="data row0 col3" >0.224778</td>
#                         <td id="T_48dcb_row0_col4" class="data row0 col4" >0.613636</td>
#                         <td id="T_48dcb_row0_col5" class="data row0 col5" >0.710526</td>
#                         <td id="T_48dcb_row0_col6" class="data row0 col6" >0.658537</td>
#             </tr>
#             <tr>
#                                 <td id="T_48dcb_row1_col0" class="data row1 col0" >MobileNet-V2_128_512_256</td>
#                         <td id="T_48dcb_row1_col1" class="data row1 col1" >0.833333</td>
#                         <td id="T_48dcb_row1_col2" class="data row1 col2" >0.166667</td>
#                         <td id="T_48dcb_row1_col3" class="data row1 col3" >0.148103</td>
#                         <td id="T_48dcb_row1_col4" class="data row1 col4" >0.716049</td>
#                         <td id="T_48dcb_row1_col5" class="data row1 col5" >0.725000</td>
#                         <td id="T_48dcb_row1_col6" class="data row1 col6" >0.720497</td>
#             </tr>
#             <tr>
#                                 <td id="T_48dcb_row2_col0" class="data row2 col0" >ResNet-34_128_1024_516</td>
#                         <td id="T_48dcb_row2_col1" class="data row2 col1" >0.806699</td>
#                         <td id="T_48dcb_row2_col2" class="data row2 col2" >0.193301</td>
#                         <td id="T_48dcb_row2_col3" class="data row2 col3" >0.174334</td>
#                         <td id="T_48dcb_row2_col4" class="data row2 col4" >0.771429</td>
#                         <td id="T_48dcb_row2_col5" class="data row2 col5" >0.885246</td>
#                         <td id="T_48dcb_row2_col6" class="data row2 col6" >0.824427</td>
#             </tr>
#     </tbody></table>

# %%
# Store best models based on model stats
best_models = tune.save_best_models(best_model_stats, MODEL_NAMES)
# Out:
# Calculating preds and stats for GoogLeNet... Complete (1/3).
# Saving model... Complete.
# Calculating preds and stats for MobileNet-V2... Complete (2/3).
# Saving model... Complete.
# Calculating preds and stats for ResNet-34... Complete (3/3).
# Saving model... Complete.
# Total time taken: 0.00 hrs 1.00 mins 25.43 secs

# %%
# Load best models
MODEL_FILENAMES = ['best_googlenet', 'best_mobilenetv2', 'best_resnet34']
best_model_layers = [[1024, 516], [512, 256], [1024, 516]]
best_models = tune._set_initial_models(N_CLASSES, h_layers=best_model_layers)
tune.load_best_models(best_models, MODEL_FILENAMES)
# Out:
# Models loaded. Utility variables available:
# 	train_losses, valid_losses, batch_size, h_layers, stats, parameters.

# %%
# Plot loss comparsion
vis.create_plots(best_models, MODEL_NAMES, figsize=(15, 4), plot_func=vis.plot_losses,
                 plot_name="best_model_losses")

# %%
# Plot ROC curves
for idx, model in enumerate(best_models):
    vis.plot_roc(model, MODEL_NAMES[idx], model.y_probas, 
                 model.y_true, figsize=(18, 12))

# %%
# Plot Confusion Matrices
for idx, model in enumerate(best_models):
    y_pred_cm, y_true_cm = tune.utils.indices_to_labels(model.y_pred, model.y_true, 
                                                        tune.labels)
    vis.plot_cm(model, MODEL_NAMES[idx], y_pred_cm, y_true_cm)

# %%
vis.plot_model_predictions(best_models, MODEL_NAMES, BATCH_SIZES, MAIN_FILEPATH, 
                           SPLIT_SIZE, SEED)
